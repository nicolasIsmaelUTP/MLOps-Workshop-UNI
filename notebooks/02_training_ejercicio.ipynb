# %% [markdown]
# # Entrenamiento del modelo — resistencia del concreto \[EJERCICIO\]
#
# Completa las celdas marcadas con `# TODO` para construir el pipeline de entrenamiento.

# %% [markdown]
# ## 1. Importar librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# TODO: importar RandomForestRegressor desde sklearn.ensemble

# TODO: importar train_test_split desde sklearn.model_selection

# TODO: importar mean_absolute_error, mean_squared_error y r2_score desde sklearn.metrics

# %% [markdown]
# ## 2. Cargar datos crudos

# %%
# TODO: cargar el archivo CSV en un DataFrame
df = ___

print(f"Forma: {df.shape}")
df.head()

# %%
df.info()

# %% [markdown]
# ## 3. Limpieza de datos

# %%
# TODO: eliminar filas duplicadas y filas con valores nulos (en una misma línea)
df = ___

print(f"Forma tras limpieza: {df.shape}")

# %% [markdown]
# ## 4. Feature Engineering
#
# Crea 3 nuevas features que combinan las variables originales:
#
# | Feature nueva | Fórmula |
# |---|---|
# | `water_cement_ratio` | `water / (cement + 1e-9)` |
# | `binder_total` | `cement + blast_furnace_slag + fly_ash` |
# | `aggregate_total` | `coarse_aggregate + fine_aggregate` |

# %%
# TODO: crear las tres nuevas columnas en el DataFrame
df["water_cement_ratio"] = ___
df["binder_total"] = ___
df["aggregate_total"] = ___

print(f"Columnas tras feature engineering: {list(df.columns)}")

# %% [markdown]
# ## 5. Preparar features y target

# %%
TARGET = "concrete_compressive_strength"

X = df.drop(columns=[TARGET])
y = df[TARGET]

# TODO: dividir en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = ___

print(f"Train: {X_train.shape}  |  Test: {X_test.shape}")

# %% [markdown]
# ## 6. Entrenar modelo

# %%
# TODO: crear un RandomForestRegressor con n_estimators=100 y random_state=42
model = ___

# TODO: entrenar el modelo con los datos de entrenamiento
___

print("Modelo entrenado.")

# %% [markdown]
# ## 7. Evaluar modelo

# %%
y_pred = model.predict(X_test)

# TODO: calcular las tres métricas de regresión
mae  = ___
rmse = ___
r2   = ___

print(f"MAE:  {mae:.3f}")
print(f"RMSE: {rmse:.3f}")
print(f"R²:   {r2:.3f}")

# Gráfico predicho vs real (ya implementado — observa cómo está construido)
fig, ax = plt.subplots(figsize=(6, 5))
ax.scatter(y_test, y_pred, alpha=0.6, edgecolors="k", linewidths=0.4)
lims = [min(y_test.min(), y_pred.min()), max(y_test.max(), y_pred.max())]
ax.plot(lims, lims, "r--", linewidth=1.5, label="Predicción perfecta")
ax.set_xlabel("Valor real (MPa)")
ax.set_ylabel("Predicción (MPa)")
ax.set_title("Predicho vs Real")
ax.legend()
plt.tight_layout()
plt.show()
